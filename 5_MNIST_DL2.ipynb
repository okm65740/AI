# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU, Conv2D
from keras.optimizers import RMSprop
from keras.utils import np_utils
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()
num_classes = 10

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(20, activation=LeakyReLU(), input_shape=(784,)))
model.add(Dense(20, activation=LeakyReLU()))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))

scores = model.evaluate(x_test, y_test)
print(scores[1])
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 60000 train samples
# 10000 test samples
# /usr/local/lib/python3.6/dist-packages/keras/activations.py:235: UserWarning: Do not pass a layer instance (such as LeakyReLU) as the activation argument of another layer. Instead, advanced activation layers should be used just like any other layer in a model.
#   identifier=identifier.__class__.__name__))
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 20)                15700
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                210
# =================================================================
# Total params: 16,330
# Trainable params: 16,330
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.5526 - accuracy: 0.8513 - val_loss: 0.2856 - val_accuracy: 0.9173
# Epoch 2/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2691 - accuracy: 0.9230 - val_loss: 0.2416 - val_accuracy: 0.9282
# Epoch 3/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2313 - accuracy: 0.9331 - val_loss: 0.2187 - val_accuracy: 0.9352
# Epoch 4/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2093 - accuracy: 0.9395 - val_loss: 0.2086 - val_accuracy: 0.9401
# Epoch 5/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1934 - accuracy: 0.9434 - val_loss: 0.1975 - val_accuracy: 0.9435
# Epoch 6/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1808 - accuracy: 0.9473 - val_loss: 0.1855 - val_accuracy: 0.9457
# Epoch 7/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1702 - accuracy: 0.9507 - val_loss: 0.1804 - val_accuracy: 0.9459
# Epoch 8/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1620 - accuracy: 0.9533 - val_loss: 0.1684 - val_accuracy: 0.9507
# Epoch 9/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1545 - accuracy: 0.9550 - val_loss: 0.1617 - val_accuracy: 0.9535
# Epoch 10/10
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1484 - accuracy: 0.9564 - val_loss: 0.1561 - val_accuracy: 0.9553
# 10000/10000 [==============================] - 0s 19us/step
# 0.955299973487854
