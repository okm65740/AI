# %%
from keras.datasets import cifar10

(x_train, y_train_), (x_test, y_test_) = cifar10.load_data()

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

from keras.utils import to_categorical
y_train = to_categorical(y_train_)
y_test = to_categorical(y_test_)

"""## Model Definition"""

from keras.models import Sequential
model = Sequential()

from keras.layers import Conv2D, MaxPool2D, Flatten, Dense

model.add(Conv2D(filters=32, 
                kernel_size=(3, 3),
                activation='relu',
                input_shape=(32, 32, 3)))

model.add(MaxPool2D())

model.add(Conv2D(filters=64,
                kernel_size=(3, 3),
                activation='relu'))
model.add(MaxPool2D())

model.add(Flatten())
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

print(model.summary())

"""## Fitting"""

history = model.fit(x_train, y_train, batch_size=50, epochs=15, verbose=1, validation_data=(x_test, y_test))

import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                23050
# =================================================================
# Total params: 42,442
# Trainable params: 42,442
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.4938 - accuracy: 0.4680 - val_loss: 1.2491 - val_accuracy: 0.5611
# Epoch 2/15
# 50000/50000 [==============================] - 5s 95us/step - loss: 1.1675 - accuracy: 0.5940 - val_loss: 1.1248 - val_accuracy: 0.6141
# Epoch 3/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.0434 - accuracy: 0.6410 - val_loss: 1.0192 - val_accuracy: 0.6490
# Epoch 4/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.9674 - accuracy: 0.6670 - val_loss: 1.0281 - val_accuracy: 0.6397
# Epoch 5/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.9120 - accuracy: 0.6878 - val_loss: 0.9721 - val_accuracy: 0.6673
# Epoch 6/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.8709 - accuracy: 0.7006 - val_loss: 0.9337 - val_accuracy: 0.6754
# Epoch 7/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.8292 - accuracy: 0.7183 - val_loss: 0.9311 - val_accuracy: 0.6835
# Epoch 8/15
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.7968 - accuracy: 0.7280 - val_loss: 0.9519 - val_accuracy: 0.6752
# Epoch 9/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.7690 - accuracy: 0.7379 - val_loss: 0.9426 - val_accuracy: 0.6765
# Epoch 10/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.7399 - accuracy: 0.7464 - val_loss: 0.9014 - val_accuracy: 0.6922
# Epoch 11/15
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.7174 - accuracy: 0.7569 - val_loss: 0.9105 - val_accuracy: 0.6952
# Epoch 12/15
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.7004 - accuracy: 0.7576 - val_loss: 0.9220 - val_accuracy: 0.6856
# Epoch 13/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.6803 - accuracy: 0.7678 - val_loss: 0.8786 - val_accuracy: 0.7074
# Epoch 14/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.6631 - accuracy: 0.7724 - val_loss: 0.8923 - val_accuracy: 0.7016
# Epoch 15/15
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.6484 - accuracy: 0.7782 - val_loss: 0.9038 - val_accuracy: 0.6960
